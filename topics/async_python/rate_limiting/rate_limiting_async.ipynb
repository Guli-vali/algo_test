# %%
💡 ID: 15 | Тип: practice | Тема: Практические паттерны
📝 Rate limiting с Semaphore
--------------------------------------------------------------------------------
ВОПРОС:
Как ограничить количество одновременных запросов? (rate limiting в async)
================================================================================

💡 Чтобы увидеть ответ, выполните: python async_trainer.py --answer 15

# %%
import asyncio

async def request_to_service():
    asyncio.sleep(3)
    return


async def main():
    asyncio.gather(*[asyncio.create_task(request_to_service), asyncio.create_task(request_to_service)])

    asyncio.sleep(0.5)
    return 'Done'
